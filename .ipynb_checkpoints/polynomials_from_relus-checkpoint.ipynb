# %%
from typing import Callable
import matplotlib
import matplotlib.pyplot as plt
import tinygrad as tg
from tinygrad.tensor import Tensor
import numpy as np
# Do not pick MacOsx because it will crash the jupyter kernel 
matplotlib.use('nbAgg')  # Replace 'TkAgg' with your preferred backend

# The goal is to express all polynomials with a neural network that only uses relu activation functions
# many thanks to Nikolaj-K @ https://www.youtube.com/watch?v=PApGm1TKFHQ for the topic
# rewrote it in a different way

# %% [markdown]
# # Utils

# %%
def plot(x: np.ndarray) -> Callable[[np.ndarray,str,str], None]:
    """
    Curries X into the plot function
    """
    def fn(y: np.ndarray, label: str, color: str) -> None:
        plt.plot(x, y, label=label, color=color)
    return lambda y,label,color : fn(y,label,color)


def plt_setup() -> None:
    plt.grid(True)
    plt.style.use('dark_background')
    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.legend(loc='best')
    plt.title("getting $a*(X^2)+b$ from Relus is the goal")
    plt.style.use('dark_background')
    return None

plt_setup()

color_cycle = matplotlib.colormaps["Spectral"]
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # STEP 1 : get X^2 from adding piecewise linear functions (triangle wave functions)

# %%
def triangle_wave(x: tg.Tensor) -> tg.Tensor:
    left = x-x.floor()
    right = x.ceil()-x
    return (left<right)*left +(left>=right)*right

def takagi(x: tg.Tensor, N:int) ->  tg.Tensor:
    #https://en.wikipedia.org/wiki/Blancmange_curve
    return tg.Tensor.stack([takagi_piece(x,i) for i in range(N)],dim=1).sum(axis=1)

def takagi_piece(x: tg.Tensor, i: int) -> tg.Tensor:
    w = 0.25 # w=1/4 gives the parabola !
    return (w**i) * triangle_wave((2**i)*x)

# %%
color_cycle = matplotlib.colormaps["Spectral"]
X=tg.Tensor.arange(0,1,0.001)
prt = plot(X.numpy())
prt(takagi(X,1).numpy(), "Takagi 1", color=color_cycle(0.0))
prt(takagi(X,2).numpy(), "Takagi 2", color=color_cycle(0.25))
prt(takagi(X,10).numpy(), "Takagi 10", color=color_cycle(0.5))
plt_setup()
plt.show()
# Out:
# <div id='62a50120-443f-4528-8861-4bb3be733964'></div>

# %% [markdown]
# # Step 2 : get the triangle wave functions from Relus

# %%
X = tg.Tensor.arange(0,1,0.001)
prt = plot(X.numpy())
# Out:
# 2024-01-17 22:39:11.318 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647

# %%
# MOVEMENT OPERATIONS ON FUNCTIONS OF TENSOR TO TENSOR

def shift(d:float, f: Callable[[tg.Tensor], tg.Tensor]) -> Callable[[tg.Tensor], tg.Tensor]:
    """
    Shifts a function by d
    towards the right if d>0
    """
    return lambda x: f(x-d)

def scale(a:float, f: Callable[[tg.Tensor], tg.Tensor]) -> Callable[[tg.Tensor], tg.Tensor]:
    """
    Scales a function by a
    """
    return lambda x: f(x/a)

def mul(a:float, f: Callable[[tg.Tensor], tg.Tensor]) -> Callable[[tg.Tensor], tg.Tensor]:
    """
    Multiplies a function by a
    """
    return lambda x: a*f(x)

def add(f: Callable[[tg.Tensor], tg.Tensor], g: Callable[[tg.Tensor], tg.Tensor]) -> Callable[[tg.Tensor], tg.Tensor]:
    """
    Adds two functions
    """
    return lambda x: f(x)+g(x)

def minus(f: Callable[[tg.Tensor], tg.Tensor]) -> Callable[[tg.Tensor], tg.Tensor]:
    """
    Flips a function along the x axis
    """
    return lambda x: -f(x)
# Out:
# 2024-01-17 22:39:11.335 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647

# %%
def relu(x: Tensor) -> Tensor:
    return x.relu()

def anti_relu(lmd:float,d:float) : 
    # this destroys the previous relus with 
    # a new one that is shifted by d and scaled by lmd=lambda
    return mul(-lmd,shift(d,relu))

def triangle_1(x: Tensor) -> Tensor:
    return relu(x)-2*relu(x-0.5)

def triangle_2(x: Tensor) -> Tensor:
    return add(relu, flip(mul(2,shift(0.25,relu))))(x)\
# Out:
# 2024-01-17 22:39:11.351 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.282 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.294 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.306 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.318 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.330 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.342 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.354 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.366 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.378 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.390 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.403 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.416 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.428 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.441 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.453 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.466 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.479 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.492 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.505 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.517 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.529 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.541 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.554 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.567 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.580 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.593 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.606 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.618 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.632 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.646 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.660 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.675 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.689 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.702 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.715 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.728 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.740 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.752 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.764 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.775 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.788 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.800 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.812 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.825 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.837 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.850 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.863 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.875 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.888 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.901 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.915 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.927 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.940 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.953 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.965 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.978 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:18.991 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.004 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.017 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.030 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.043 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.056 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.070 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.084 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.098 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.112 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.128 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.141 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.154 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.166 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.178 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.191 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.204 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.218 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.231 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.245 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.258 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.273 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.288 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.302 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.317 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.331 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.344 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.358 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.371 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.383 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.396 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.409 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.422 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.435 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.448 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.462 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.475 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.490 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.504 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.518 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.532 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.548 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.561 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.574 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.587 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.600 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.613 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.626 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.639 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.652 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.665 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.679 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.693 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.706 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.721 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.734 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.748 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.762 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.775 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.787 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.800 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.812 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.825 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.837 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.850 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.862 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.876 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.890 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.903 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.918 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.932 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.945 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.959 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.975 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:19.988 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.001 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.014 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.027 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.039 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.052 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.066 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.079 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.093 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.106 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.119 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.135 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.149 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.162 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.177 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.191 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.204 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.216 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.228 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.240 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.253 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.265 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.278 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.290 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.302 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.315 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.327 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.340 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.352 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.365 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.378 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.390 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.402 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.413 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.426 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.438 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.450 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.462 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.475 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.487 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.500 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.512 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.525 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.537 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.550 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.562 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.575 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.588 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.602 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.615 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.627 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.639 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.652 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.664 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.677 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.691 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.704 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.717 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.731 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.744 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.758 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.772 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.786 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.800 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.813 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.827 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.840 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.852 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.864 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.877 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.889 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.901 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.914 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.925 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.937 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.950 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.962 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.974 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.986 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:20.998 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.010 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.023 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.035 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.048 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.060 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.072 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.085 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.097 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.109 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.121 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.133 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.145 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.157 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.169 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.181 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.193 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.206 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.218 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.230 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.243 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.255 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.268 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.280 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.293 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.305 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.316 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.329 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.341 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.353 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.366 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.378 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.390 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.403 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.415 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.428 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.441 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.454 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.466 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.478 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.490 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.502 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.514 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.526 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:21.537 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# ...
# 2024-01-17 22:39:59.237 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.250 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.262 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.275 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.287 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.300 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.312 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.325 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.337 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.350 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.362 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.374 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.386 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.399 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.410 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.422 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.434 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.446 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.458 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.471 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.483 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.496 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.508 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.521 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.533 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.546 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.558 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.570 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.583 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.595 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.608 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.620 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.633 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.646 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.658 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.671 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.683 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.696 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.708 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.721 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.735 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.748 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.761 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.773 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.786 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.799 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.811 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.824 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.837 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.850 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.862 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.875 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.887 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.900 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.914 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.927 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.941 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.954 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.967 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.979 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:39:59.992 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.004 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.017 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.029 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.042 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.054 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.067 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.079 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.092 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.105 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.119 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.132 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.146 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# 2024-01-17 22:40:00.158 python[5809:68889] *** Assertion failure in +[NSEvent otherEventWithType:location:modifierFlags:timestamp:windowNumber:context:subtype:data1:data2:], NSEvent.m:647
# ERROR:tornado.application:Exception in callback functools.partial(<function Kernel.enter_eventloop.<locals>.advance_eventloop at 0x1048bb0d0>)
# Traceback (most recent call last):
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/tornado/ioloop.py", line 750, in _run_callback
#     ret = callback()
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 479, in advance_eventloop
#     eventloop(self)
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/ipykernel/eventloops.py", line 353, in loop_cocoa
#     if kernel.shell_stream.flush(limit=1):
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 533, in flush
#     self._rebuild_io_state()
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 698, in _rebuild_io_state
#     self._update_handler(state)
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 715, in _update_handler
#     if state & self.socket.events:
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/zmq/sugar/attrsettr.py", line 55, in __getattr__
#     return self._get_attr_opt(upper_key, opt)
#   File "/Users/hcornier/Documents/GitHub/aiforbattle/venv/lib/python3.9/site-packages/zmq/sugar/attrsettr.py", line 67, in _get_attr_opt
#     return self.get(opt)
#   File "zmq/backend/cython/socket.pyx", line 481, in zmq.backend.cython.socket.Socket.get
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/enum.py", line 384, in __call__
#     return cls.__new__(cls, value)
#   File "/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/enum.py", line 674, in __new__
#     if type(value) is cls:
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
X = Tensor.arange(0,1,1000)

prt = plot(relu(X).numpy()) # relu : the starting point

prt(add(relu,minus(shift(0.5,relu)))(X).numpy(), "mistake : remove only one shifted Relu", color=color_cycle(0.0))

plt_setup()
plt.show()

# We cut in half the frist relu and create a triangle
triangle_1 = add(relu,anti_relu(2,0.5))(X).numpy()

prt(triangle_1, "add anti_relu(2,0.5)", color=color_cycle(0.25))

plt_setup()
plt.show()

triangle_2 = add(relu,anti_relu(4,0.25))(X).numpy()

prt(triangle_2, "add anti_relu(4,0.25)", color=color_cycle(0.5))

plt_setup()
plt.show()

triangle_3 = add(relu,anti_relu(8,0.125))(X).numpy()

prt(triangle_3, "add anti_relu(8,0.125)", color=color_cycle(0.75))

triangle_4 = add(relu,anti_relu(16,0.0625))(X).numpy()

prt(triangle_4, "add anti_relu(16,0.0625)", color=color_cycle(1.0))

plt_setup()
plt.show()

#triangle_1_25 = add(triangle_1,minus() (X).numpy()

# prt(add(relu,mul(2,shift(0.5,flip(relu))))(X).numpy(), "shift 0.5 relu", color=color_cycle(0.0))
# prt(triangle_2(X).numpy(), "tinygrad tensor", color=color_cycle(0.5))
# prt(triangle_2(X).numpy(), "tinygrad tensor", color=color_cycle(0.5))
